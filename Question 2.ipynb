# %% [markdown]
# ### Using `startup_funding.csv`, cluster startups based on funding amount, sector, and stage. Provide insights into startup ecosystem patterns.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv("startup_funding.csv")

# %%
le_sector = LabelEncoder()
le_stage = LabelEncoder()

# %%
df["Sector_enc"] = le_sector.fit_transform(df["Sector"])
df["Stage_enc"] = le_stage.fit_transform(df["Stage"])

# %%
X = df[["FundingAmount_CrINR", "Sector_enc", "Stage_enc"]]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
df["Cluster"] = kmeans.fit_predict(X_scaled)
# Out:
# C:\Users\shani\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
print(df[["StartupName", "Sector", "Stage", "FundingAmount_CrINR", "Cluster"]].head())
# Out:
#   StartupName      Sector   Stage  FundingAmount_CrINR  Cluster
# 0   Startup_1     FinTech    Seed                  8.5        2
# 1   Startup_2      EdTech   Early                 32.4        0
# 2   Startup_3  HealthTech  Growth                110.6        1
# 3   Startup_4    AgriTech    Seed                  6.2        2
# 4   Startup_5  E-Commerce  Growth                145.8        0

# %%
print("\nCluster wise average funding:")
print(df.groupby("Cluster")["FundingAmount_CrINR"].mean())
# Out:
# Cluster wise average funding:
# Cluster
# 0     80.220000
# 1    100.486957
# 2      8.080952
# 3    570.500000
# Name: FundingAmount_CrINR, dtype: float64

# %% [markdown]
# #### 4 clustersum avarde averagum

# %%
print("\nCluster Sizes:")
print(df["Cluster"].value_counts())
# Out:
# Cluster Sizes:
# 1    23
# 2    21
# 0    20
# 3     6
# Name: Cluster, dtype: int64

# %% [markdown]
# #### oro clustersile startup companiesnte enam

# %%
print("\nAverage Funding per Cluster:")
print(df.groupby("Cluster")["FundingAmount_CrINR"].mean())
# Out:
# Average Funding per Cluster:
# Cluster
# 0     80.220000
# 1    100.486957
# 2      8.080952
# 3    570.500000
# Name: FundingAmount_CrINR, dtype: float64

# %%
print("\nDominant Stage per Cluster:")
print(df.groupby("Cluster")["Stage"].agg(lambda x: x.value_counts().index[0]))
# Out:
# Dominant Stage per Cluster:
# Cluster
# 0     Early
# 1    Growth
# 2      Seed
# 3      Late
# Name: Stage, dtype: object

# %% [markdown]
# #### oro clusterile dominant stage

# %%
print("\nFunding Range per Cluster:")
print(df.groupby("Cluster")["FundingAmount_CrINR"].agg(["min", "max"]))
# Out:
# Funding Range per Cluster:
#            min    max
# Cluster
# 0         26.3  175.6
# 1         35.8  180.2
# 2          4.9   12.6
# 3        380.4  780.9

# %% [markdown]
# #### funding range
